# %% [markdown]
# ### LLM-based data extraction from scientific paper using mistral-small

# %%
from config import MISTRALAI_API_KEY
from mistralai import Mistral
import requests
import pandas as pd
import json
import time

model = "mistral-small-2503"
client = Mistral(api_key=MISTRALAI_API_KEY)

# %%
headers = {
    "Authorization": f"Bearer {MISTRALAI_API_KEY}"
}

response = requests.get("https://api.mistral.ai/v1/models", headers=headers)

if response.status_code == 200:
    models = response.json()
    for model in models["data"]:
        if "mistral-small-2503" in model["id"]:
            print(model)
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# {'id': 'mistral-small-2503', 'object': 'model', 'created': 1746076564, 'owned_by': 'mistralai', 'capabilities': {'completion_chat': True, 'completion_fim': False, 'function_calling': True, 'fine_tuning': False, 'vision': True, 'classification': False}, 'name': 'mistral-small-2503', 'description': 'Official mistral-small-2503 Mistral AI model', 'max_context_length': 131072, 'aliases': ['mistral-small-latest'], 'deprecation': None, 'default_model_temperature': 0.3, 'type': 'base'}

# %%
rs = 'Safdar_Siddique_Khan_2024'
studies = pd.read_csv(f'../csvs/{rs}.csv')
studies = studies[studies['oa_status'] == True]
studies.head()
# Out:
#                          doi  url                     study  oa_status  \
# 2            10.1145/3234942  NaN       Andalibi et al 2018       True
# 6   10.1177/2056305120974610  NaN           Deal et al 2020       True
# 14  10.1177/2056305120984447  NaN       Madden and Alt 2021       True
# 16  10.1177/1461444818820069  NaN         Mendes et al 2019       True
# 17             10.2196/13837  NaN  Modrek and Chakalov 2019       True
#
#           first_author                                              title  \
# 2     Nazanin Andalibi  Social Support, Reciprocity, and Anonymity in ...
# 6    Bonnie-Elene Deal  â€œI Definitely Did Not Report It When I Was R...
# 14    Stephanie Madden  Know Her Name: Open Dialogue on Social Media a...
# 16     Kaitlynn Mendes  Digitized narratives of sexual violence: Makin...
# 17  PhD Sepideh Modrek  The #MeToo Movement in the United States: Text...
#
#                                              abstract   published  \
# 2   \nSeeking and providing support is challenging...     2018-10
# 6   \nThe "Me Too" movement, founded by activist T...     2020-10
# 14  \nInnovative justice focuses on crime victim n...     2021-01
# 16  \nIn this article, we argue that social media ...  2018-12-29
# 17  \nBackground:The #MeToo movement sparked an in...  2019-09-03
#
#                                            journal  \
# 2   ACM Transactions on Computer-Human Interaction
# 6                           Social Media + Society
# 14                          Social Media + Society
# 16                             New Media & Society
# 17            Journal of Medical Internet Research
#
#                                     publisher  \
# 2   Association for Computing Machinery (ACM)
# 6                           SAGE Publications
# 14                          SAGE Publications
# 16                          SAGE Publications
# 17                     JMIR Publications Inc.
#
#                                                  body  \
# 2   INTRODUCTION\nSocial media platforms are often...
# 6   \nThe "Me Too" movement was founded in 2006 by...
# 14  \nIn March 2016, Brock Turner was convicted of...
# 16  Introduction\nIn 2012, 16 students enrolled in...
# 17  Introduction\nPublic discourse on sensitive to...
#
#     nb_tokens_openai_tiktoken  nb_tokens_mistral_sentencepiece
# 2                        5956                             6882
# 6                        6989                             8163
# 14                       6754                             7629
# 16                       6901                             7986
# 17                       6364                             7166

# %%
studies = studies.to_dict('records')

# %%
with open('utils/data_elements_doco.txt') as f:
    data_elements_doco = f.read()

with open(f'utils/data_elements_{rs}.txt') as f:
    specific_data_elements = f.read()

# %%
system_prompt = f"""
    - You are an expert in data extraction for literature reviews in the social sciences.\n
    - You extract data from the paper provided by the user, based on the data elements specified below:\n
    {specific_data_elements}.

    - The data extracted should be a few keywords only, no full sentences.\n
    - Return the annotated paper into a valid JSON object, with one field for each data element.\n

    If the information from a specific data element is not available in the paper, simply return NA for that element.\n
    Return the data as closely as they appear in the original paper. do not modify the text.\n
    Do not include information outside the given paper. Do not make up an answer if the information is not available.
"""

# %%
system_prompt_doco = f"""
    - You are an expert at extracting semantic information extraction from scientific papers.\n
    - You extract data from the paper provided by the user, based on the classes of the Discourse Elements Ontology (DEO) specified below:\n 
    {data_elements_doco}.

    - The data extracted should be a few keywords only, no full sentences.\n
    - Return the annotated paper into a valid JSON object with one field for each DEO element.\n

    If the information from a specific data class is not available in the paper, simply return NA for that element.\n
    Return the data as closely as they appear in the original paper, do not modify the text\n
    Do not include information outside the given paper. Do not make up an answer if the information is not available.
"""

# %%
data_extraction = [] 
for study in studies:
    user_prompt = f"Paper to annotate: {study['body']}"

    chat_response = client.chat.complete(
        model = "mistral-small-2503",
        messages = [
            {
                "role": "system",
                "content": f"{system_prompt}",
            },
            {
                "role": "user",
                "content": f"{user_prompt}",
            }
        ],
        response_format = {
            "type": "json_object"
        },
    )
    study_data = {'study': study ['study']}
    study_data.update(json.loads(chat_response.choices[0].message.content))

    data_extraction.append(study_data)
    time.sleep(1)

data_extraction = pd.DataFrame(data_extraction)
data_extraction.to_csv(f'../llm-based_extraction/mistral-small-2503/specific_extraction_{rs}.csv', index=False)

# %%
data_extraction
# Out:
#                           study Geographical breadth of research  \
# 0                    Ahmad 2021                 Perth, Australia
# 1            Bernard et al 2015             Bremerhaven, Germany
# 2            Dadhich et al 2021                            India
# 3                       Fu 2014                               NA
# 4            Fu and Carmen 2015    Oregon, Washington, and Idaho
# 5   Grammenis and Mourikis 2020                      Greece, USA
# 6               Guo and Xu 2023            United States, Canada
# 7              Lindy et al 2015                               NA
# 8               Liu and Fu 2018                               NA
# 9      Singley and Natches 2017          U.S. academic libraries
# 10                    Wang 2022                               NA
# 11          Yeh and Walter 2016                               NA
#
#    Analysis method                                       Data sources  \
# 0     Quantitative          Ebook Library (EBL) transaction log files
# 1    Mixed methods  PANGAEA repository, Baseline Surface Radiation...
# 2    Mixed methods                            Surveys, secondary data
# 3     quantitative  online job postings, vendor staffing proposals...
# 4      Qualitative  direct observation, participant observation, e...
# 5      Qualitative  Literature review, semi-structured interviews,...
# 6      Qualitative                                             Survey
# 7     quantitative  questionnaire, direct observation, one-on-one ...
# 8               NA  Marshall Breeding's annual product reports, Li...
# 9     Quantitative                                      Online survey
# 10              NA                                                 NA
# 11     qualitative                                                 NA
#
#                                          Participants  \
# 0                                    ECU e-book users
# 1   Experts from computer science, a scientific di...
# 2         Librarians and users of Indian universities
# 3                                  systems librarians
# 4                      forty-one librarians and staff
# 5   Academic librarians, IT professionals, vendor ...
# 6   Deans, directors of the library, university li...
# 7   library users, library staff, library supervisors
# 8                                                  NA
# 9                 Library staff involved in ERM tasks
# 10                                                 NA
# 11                          staff from four libraries
#
#                                      Participant size  \
# 0                            8,482, 9,353, and 11,690
# 1                                                  NA
# 2                                                 510
# 3                                                  52
# 4                                                  NA
# 5   5 academic libraries, 1 vendor representative,...
# 6                                                  NA
# 7                                                  NA
# 8                                                  NA
# 9                                                 299
# 10                                                 NA
# 11                                                 NA
#
#              Roles of Library Service Platforms (LSP)  \
# 0                                                  NA
# 1   Content-based overview visualization, visual q...
# 2                                                  NA
# 3   systems administration, system implementer, op...
# 4                                                  NA
# 5   Systems Administration, Cataloging, Acquisitio...
# 6   Resource management, acquisitions, user reques...
# 7                                                 NaN
# 8   Resource sharing, cooperative acquisitions, e-...
# 9   ERM, integrated print and electronic resource ...
# 10  [personalized information service system, medi...
# 11  management of both print and electronic collec...
#
#                        Challenges that libraries face  \
# 0                                                  NA
# 1   Varying similarity notions, different time int...
# 2                                                  NA
# 3   transition from traditional ILS to next-genera...
# 4   Electronic Resources, Primo, Acquisitions, Cat...
# 5   Inadequate funding, increasing demands for ser...
# 6   Cost sharing, workflow design, policy, collabo...
# 7   declining budget, complex library system, stat...
# 8   funding, evolving role of the library, changin...
# 9   Manual workarounds, patchwork of systems, lack...
# 10  [lack of a macro-control mechanism, coordinati...
# 11  careful selection process, top management invo...
#
#                    Roles of Library Service Platforms
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   circulation management, online book procuremen...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
