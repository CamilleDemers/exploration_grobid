# %% [markdown]
# ### LLM-based data extraction from scientific paper using mistral-small

# %%
from config import MISTRALAI_API_KEY
from mistralai import Mistral
import requests
import pandas as pd
import json
import time

model = "mistral-small-2503"
client = Mistral(api_key=MISTRALAI_API_KEY)

# %%
headers = {
    "Authorization": f"Bearer {MISTRALAI_API_KEY}"
}

response = requests.get("https://api.mistral.ai/v1/models", headers=headers)

if response.status_code == 200:
    models = response.json()
    for model in models["data"]:
        if "mistral-small-2503" in model["id"]:
            print(model)
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# {'id': 'mistral-small-2503', 'object': 'model', 'created': 1746061539, 'owned_by': 'mistralai', 'capabilities': {'completion_chat': True, 'completion_fim': False, 'function_calling': True, 'fine_tuning': False, 'vision': True, 'classification': False}, 'name': 'mistral-small-2503', 'description': 'Official mistral-small-2503 Mistral AI model', 'max_context_length': 131072, 'aliases': ['mistral-small-latest'], 'deprecation': None, 'default_model_temperature': 0.3, 'type': 'base'}

# %%
rs = 'Shahzad_Khan_2023'
studies = pd.read_csv(f'../csvs/{rs}.csv')
studies = studies[studies['oa_status'] == True]
studies.head()
# Out:
#                               doi  \
# 0  10.1080/00049670.2006.10721856
# 1                               -
# 4     10.1515/9783598440168.3.157
# 6                               -
# 8                             NaN
#
#                                                  url                    study  \
# 0                                                NaN  Cossham and Fields 2006
# 1  https://journals.unizik.edu.ng/lrj/article/vie...   Anyaegbu and Wali 2020
# 4                                                NaN     Chan and Auster 2005
# 6   https://digitalcommons.unl.edu/libphilprac/2042/  Dina and Olowosoke 2018
# 8    https://digitalcommons.unl.edu/libphilprac/5220   Anyaegbu and Wali 2020
#
#    oa_status       first_author  \
# 0       True     Amanda Cossham
# 1       True           Anyaegbu
# 4       True               Chan
# 6       True               Dina
# 8       True  Dr Wisdom O Anyim
#
#                                                title  \
# 0  Keeping the roses watered: the continuing prof...
# 1  INFLUENCE OF STAFF TRAINING AND DEVELOPMENT ON...
# 4  Understanding Librarians Motivation to Partici...
# 6  The Effect of Motivation and Job Performance o...
# 8  Cross-training and Development of Librarians f...
#
#                                             abstract published  \
# 0  \r\nContinuing professional development is a n...   2006-08
# 1                                                NaN      2019
# 4                                                NaN      2005
# 6                                                NaN      2018
# 8  \r\nCross-training exercise is very important ...      2011
#
#                           journal           publisher  \
# 0  The Australian Library Journal  Informa UK Limited
# 1                             NaN                 NaN
# 4                             NaN                 NaN
# 6                             NaN                 NaN
# 8  Scholarly Journal of Education                 NaN
#
#                                                 body  \
# 0  \r\nT he mAiNteNANce Of prOfessiONAl educAtiON...
# 1  Introduction\nUniversity libraries are academi...
# 4  Introduction\nIn twenty first century librarie...
# 6  Introduction\nMotivation is a process that eli...
# 8  Introduction\r\nUniversity library is a very i...
#
#    nb_tokens_openai_tiktoken  nb_tokens_mistral_sentencepiece
# 0                       6095                             6777
# 1                       6221                             6916
# 4                       5768                             6392
# 6                       4030                             4556
# 8                       5496                             6204

# %%
studies = studies.to_dict('records')

# %%
with open('utils/data_elements_doco.txt') as f:
    data_elements_doco = f.read()

with open(f'utils/data_elements_{rs}.txt') as f:
    specific_data_elements = f.read()

# %%
system_prompt = f"""
    - You are an expert in data extraction for literature reviews in the social sciences.\n
    - You extract data from the paper provided by the user, based on the data elements specified below:\n
    {specific_data_elements}.

    - The data extracted should be a few keywords only, no full sentences.\n
    - Return the annotated paper into a valid JSON object, with one field for each data element.\n

    If the information from a specific data element is not available in the paper, simply return NA for that element.\n
    Return the data as closely as they appear in the original paper.\n
    Do not include information outside the given paper. Do not make up an answer if the information is not available.
"""

# %%
system_prompt_doco = f"""
    - You are an expert at extracting semantic information extraction from scientific papers.\n
    - You extract data from the paper provided by the user, based on the classes of the Discourse Elements Ontology (DEO) specified below:\n 
    {data_elements_doco}.

    - The data extracted should be a few keywords or a very short summarized sentence, but no full sentences.\n
    - Return the annotated paper into a valid JSON object with one field for each DEO element.\n

    If the information from a specific data class is not available in the paper, simply return NA for that element.\n
    Return the data as closely as they appear in the original paper.\n
    Do not include information outside the given paper. Do not make up an answer if the information is not available.
"""

# %%
data_extraction = [] 
for study in studies:
    user_prompt = f"Paper to annotate: {study['body']}"

    chat_response = client.chat.complete(
        model = model,
        messages = [
            {
                "role": "system",
                "content": f"{system_prompt}",
            },
            {
                "role": "user",
                "content": f"{user_prompt}",
            }
        ],
        response_format = {
            "type": "json_object"
        }
    )
    study_data = {'study': study ['study']}
    study_data.update(json.loads(chat_response.choices[0].message.content))

    data_extraction.append(study_data)
    time.sleep(2)

data_extraction = pd.DataFrame(data_extraction)
data_extraction.to_csv(f'../llm-based_extraction/specific_extraction_{rs}.csv', index=False)

# %%
data_extraction
# Out:
#                                study        Country  \
# 0            Cossham and Fields 2006    New Zealand
# 1             Anyaegbu and Wali 2020        Nigeria
# 2               Chan and Auster 2005         Canada
# 3            Dina and Olowosoke 2018        Nigeria
# 4             Anyaegbu and Wali 2020             NA
# 5                      Chidiadi 2019        Nigeria
# 6    Madukoma, Akpa, and Okafor 2014        Nigeria
# 7              Hamid and Younus 2021       Pakistan
# 8                          Issa 2021        Nigeria
# 9        Venturella and Breland 2019             NA
# 10  Kendrick, Leaver, and Tritt 2013  United States
# 11                  Imam et al. 2021        Nigeria
# 12               Hamp and Lewis 2013      Australia
# 13              Jiang and Zhang 2011          China
# 14  Lamptey, Boateng, and Antwi 2013          Ghana
#
#                        Motivational factors toward PD  \
# 0   personal satisfaction, preparation for a desir...
# 1                                                  NA
# 2   professional competence, patron service, colle...
# 3   reward, internship training, transformational ...
# 4   [professional growth, job satisfaction, non-mo...
# 5                                                  NA
# 6   training, motivation, salary packages, conduci...
# 7                                                  NA
# 8   feeling of being involved at work, good workin...
# 9   [upgrading knowledge, abilities, competencies,...
# 10  More funding, local CPD opportunities, more ti...
# 11                                                 NA
# 12  career aspirations, standards of professional ...
# 13                                                 NA
# 14  career development, study leave with pay outsi...
#
#        Relation between Motivation and Librarians' PD  \
# 0   personal satisfaction, preparation for a desir...
# 1                                                  NA
# 2   significant predictor of participation in both...
# 3   Motivation enhances library personnel effectiv...
# 4   [cross-training, development, training, job pe...
# 5                                                  NA
# 6   training motivates library employees, motivati...
# 7                                                  NA
# 8   job motivation, job satisfaction, job performa...
# 9   [PD helps librarians keep pace with technology...
# 10                                                 NA
# 11                                                 NA
# 12                                                 NA
# 13                                                 NA
# 14                                                 NA
#
#         Challenges in implementation of PD activities
# 0   employer reluctance, budgets, sharing of limit...
# 1                                                  NA
# 2   heavy workload, lack of interest, lack of libr...
# 3                                                  NA
# 4   [distraction, lack of enthusiasm, dissatisfact...
# 5                                                  NA
# 6                                                  NA
# 7                                                  NA
# 8   low salaries, irregular promotional structure,...
# 9   [scheduling conflicts, devote time to the acti...
# 10  Funding, travel distance, time, staff, budget ...
# 11  [inadequate funding, no written capacity build...
# 12  time, cost, accessibility, awareness, suitable...
# 13  [deficient funds, price rising of books and pe...
# 14  bureaucracy, frustrations in the system, lack ...
